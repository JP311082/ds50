# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Seaborn Exercises

# %% [markdown]
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ### The Data
#
# Loading the Titanic dataset (it is actually included in the Seaborn package!):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Exercises
#
# ** Recreate the plots below using the Titanic dataframe. **
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell below that one which won't overwrite that plot!* **

# %%
## DO NOT RUN!

# %%
sns.jointplot(data=titanic, x='fare', y='age')

# %%
## DO NOT RUN!

# %%
sns.distplot(titanic.fare, bins=30, kde=False, color='red')
# Out:
# <AxesSubplot:xlabel='fare'>

# %%
## DO NOT RUN!

# %%
sns.boxplot(x='class', y='age',data=titanic, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
## DO NOT RUN!

# %%
sns.swarmplot(data=titanic, x='class', y='age')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
## DO NOT RUN!

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE ABOVE
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
## DO NOT RUN!
# Out:
# Text(0.5,1,'titanic.corr()')

# %%
sns.heatmap(data=titanic.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
## DO NOT RUN!

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE ABOVE
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
