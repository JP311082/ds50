# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Matplotlib Exercise

# %% [markdown]
# For each plot, remember the best practises. Make sure your plot is:
#
# - labelled (both axes and a title)
# - big enough to be legible
# - appropriately coloured
# - scaled appropriately

# %% [markdown]
# #### 1. Change the plotting style.
#
# Find a style you like here: [https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html](https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html)

# %%
#
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# #### 2. Read in the `ufo` dataset from the `datasets` folder into a DataFrame

# %%
df = pd.read_csv('../data/ufo.csv')
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# #### 3. Use an appropriate plot to visualise the number of times each shape was reported

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('UFO sightings by shape')
ax.set_ylabel('sdf')
df['Shape Reported'].value_counts().plot(kind='bar', ax=ax)
# Out:
# <AxesSubplot:title={'center':'UFO sightings by shape'}, ylabel='sdf'>

# %% [markdown]
# #### 4. Plot a horizontal bar chart to see how often each colour was reported.
#
# Make sure the bars are in **descending** order

# %%
fig, ax = plt.subplots(figsize=(10,6))

df['Colors Reported'].value_counts().sort_values(ascending=True).plot(kind='barh', ax=ax)
plt.show()

# %%
#

# %% [markdown]
# #### 5. Plot "sightings per year" for the state of New York.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80543 entries, 0 to 80542
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             80496 non-null  object
#  1   Colors Reported  17034 non-null  object
#  2   Shape Reported   72141 non-null  object
#  3   State            80543 non-null  object
#  4   Time             80543 non-null  object
#  5   Year             80543 non-null  object
# dtypes: object(6)
# memory usage: 3.7+ MB

# %%
df['Time'] = pd.to_datetime(ufo['Time'], format='%m/%d/%Y %H:%M')

# %%
df['Year'] = df['Time'].dt.year
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
fig, ax = plt.subplots(figsize=(10,6))
df[df['State'] == 'NY'].value_counts('Year').sort_index().plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Year'>
