# %% [markdown]
# <img src="assets/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Introduction to Web Services and APIs
#
#
#
# ---
# ![](assets/opening.png)

# %% [markdown]
# # <font style = 'color:blue'>Agenda</font>
#
# #### Housekeeping
# #### Part 1: Introduction to Web Services & APIs
# #### BREAK
# #### Part 2: Start working on Unit Project 3

# %% [markdown]
# # <font style = 'color:blue'> Housekeeping</font>

# %% [markdown]
# # <font style = 'color:blue'> Learning Objectives </font>
# *After this lesson, you will be able to:*
# - Identify relevant HTTP Verbs & their uses.
# - Describe Application Programming Interfaces (APIs) and know how to make calls and consume API data.
# - Access public APIs and get information back.
# - Read and write data in JSON format.
# - Use the `requests` library.

# %% [markdown]
# <a name="intro"></a>
# # <font style = 'color:blue'> Introduction to APIs </font>
#
# ---
#
# In this lesson, we will be diving into the world of APIs. We will take a tour of one of the most accessible sources of data on the Internet.
#
# You will learn:
# - **What is meant by an "API"**
# - **Common API use cases**
# - **How to read API documentation**
# - **General development workflow with APIs**

# %% [markdown]
# <a id='what-is-api'></a>
# ## What is an API?
#
# ---
#
# An **API (Application Programming Interface)** is a set of routines, protocols, and tools for building software applications. It specifies how software components should interact.
#
# We are used to many **interfaces** in real life. For example:
#
# - **A door handle.** We don't care how a door works. All that we expect is that pushing or pulling the handle will open the door. In fact, the way the door opens (theoretically) could be entirely different each time we use the door.
#
# - **File->Print.** We don't care how the computer prints the document. All that we expect is that using the Print option in the File menu will print the document. In fact, the way the computer prints it could change every time the program is updated.

# %% [markdown]
# In programming, we also use many interfaces. The interface we use to a programming library is its function calls. For example:
#
# - **Matplotlib `plot()`**: We don't care how the `plot()` function works. All that we expect is that calling this function (with appropriate parameters) will plot the data and return a graphic. In fact, how the function works can completely change from version to version.
#
# **These are APIs -- Application Programming Interfaces.** The functions that you call and the parameters you call them with make up the interface to a programming library.

# %% [markdown]
# #### Web APIs
#
# - **How does this extend to the web?** A Web API is a list of function calls that are made to remote servers. The function call is sent by encoding it as a URL (technically, as an HTTP request -- we'll discuss these later!). The function call typically returns a string of text (e.g. JSON).

# %% [markdown]
# APIs are a way developers connect functionality to data, devices, and other resources they provide.
#
# Some examples that APIs can assist with are:
#
# - Connectivity to a variety of databases
# - Python modules that can turn LED lights on and off
# - Application that runs on native Windows, OSX, or Linux
# - Libraries that post content on Twitter, Facebook, Yelp, or LinkedIn
# - Web services for accessing currency or stock prices

# %% [markdown]
# More abstract examples:
# - Adding your own functions to Numpy itself
# - Extending Python with C code
# - Testing Frameworks
#
# In the context of data science, APIs are a very common method to interact with data hosted by third parties and most commonly provided by **Web Service APIs**, or just **Web APIs**.

# %% [markdown]
# ### Why did APIs become popular?
#
# APIs became popular for many reasons:
#
# - Easy to use for JavaScript programmers
# - Prevent website scraping
# - Allow a website's brand to be incorporated into other websites
#
# More importantly, in the modern web, nearly every website uses **internal APIs** for shuttling dynamic data between the browser and the website.

# %% [markdown]
# <a id='famous'></a>
# <a id='facebook'></a>
#
# ### Famous APIs:  Facebook Graph API
#
# Facebook provides an API for interacting with their service.  At a glance:
#
# - View your posts
# - View websites, people, posts, pages that you've liked
# - View activity on apps from you and your friends
#   - Movies watched
#   - Music listened
#   - Games played
# - View places traveled / check-ins
# - Relationships

# %% [markdown]
# <a id='yelp'></a>
# ### Famous APIs:  Yelp API
#
# Yelp provides a way for developers to access:
#
# - Reviews
#  - Services
#  - Restaraunts / Bars / Cafes
#  - Businesses
# - Business meta-data

# %% [markdown]
# <a id='echonest'></a>
# ### Famous APIs:  The Echo Nest
#
# The Echo Nest consolidates access to many entertainment service APIs in one place.  It has a huge list of features and connected services including:
#
# - Spotify
# - Pandora
# - Rdio
# - Gracenote
# - SoundHound
# - Shazam

# %% [markdown]
# Some Echonest features include:
#
# - Music waveform identification (like Shazam, Soundhound music ID)
# - Playlist recommendations
# - Detailed artist, album, and track lookup
#  - Bio / Origins / Contemporaries / Noteworthy Accomplishments
#  - Official twitter / website / social media links
#  - BPM / Mood / Popularity / Genre(s)
#  - Images / Videos / Media
# - Detailed movie, actor, product lookup
# - Concert Schedules and ticket metadata

# %% [markdown]
# <a id='web-apis'></a>
# ## Web APIs
#
# ---
#
#
# The prevelance of web APIs have increased 10x with the rise of Javascript and advent of web programming techniques. These allow for the transmission of small pieces of data without having to refresh the entire page.
#
# With the growth of highly interactive websites powered by modern Javascript, many languages have started co-opting standards to communicate data to and from web servers for two big reasons:
# - Ease of integration
# - Consistent standards
#
# Modern Javascript allows for **asynchronous requests**, or **AJAX** (Asynchronous JavaScript And XML). This allows websites to send/receive data in the background, e.g. to/from APIs.

# %% [markdown]
# <a name="api-calls"></a>
# ## Making API calls
#
# ---
#
# API calls are really a fancy term for making _HTTP requests_ (in the context of web APIs) to a server and sending/receiving structured data from that endpoint (URL). We are still communicating with URLs, however instead of receiving a string of HTML, we receive data.
#
# [Representational state transfer (REST)](https://spring.io/understanding/REST) is the most common architecture style for passing information to and from these API endpoints.

# %% [markdown]
# ### API Tokens
#
# Many APIs are free to access. You first need to register as a developer and obtain an authorization key. In most cases, this is also accompanied by a temporary token that needs to be renewed after some time. This is a way to prevent abuse on the server's resources.
#
# - For example, the Twitter API requires a token that is used to track how many requests each user makes. Each user can retrieve a limited number of tweets, unless they pay for premium services.
#
# Before we start consuming API services, it is important to understand the fundamentals of the underlying communication layer: **HTTP**.

# %% [markdown]
# <a id='http'></a>
# # <font style = 'color:blue'> HTTP </font>
#
# ---
#
# **HTTP (HyperText Transfer Protocol)** is a protocol - a system of rules - that determines how web pages (see:'hypertext') get sent (see:'transferred') from one place to another. Among other things, it defines the format of the messages passed between HTTP clients and HTTP servers.
#
# Since the web is a service, it works through a combination of **clients** (that _make_ requests) and **servers** (that _receive_ requests).

# %% [markdown]
# ### The HTTP client
#
# **HTTP clients** make or generate **HTTP requests**. Some types of clients are:
#
# * Browsers - Chrome, Firefox and Safari.
# * Command Line programs - [curl](http://curl.haxx.se/docs/) and [wget](http://www.gnu.org/software/wget/manual/wget.html).
# * Application code -  Python Requsts, Scrapy, Mechanize
#
# HTTP clients respond to HTTP responses from a **web server**/**HTTP server**. A web server is just a computer that listens for and responds to HTTP requests.

# %% [markdown]
# ### HTTP and web servers
#
# All _web servers_ receive _HTTP requests_ and generate _HTTP responses_. Often web servers are just the middleman, passing HTTP requests and responses between the client and web application. Two of the most popular _HTTP or Web servers_ are [Apache](http://httpd.apache.org/) and [Nginx](http://nginx.com/), But there are many different [web servers](https://www.tutorialspoint.com/internet_technologies/web_servers.htm) out there.

# %% [markdown]
# <a id='web-app'></a>
# ## Web applications
#
# ---
#
# Web applications are programs that run on a web server. They process the HTTP requests that the server receives and generate HTTP responses.
#
# ![HTTP Request and Response](assets/request-response.png)

# %% [markdown]
# Lost? Here's the step-by-step.
#
# 1. A client sends a HTTP request to a HTTP server running on a remote machine.
#   * The _hostname_, given in the URL, indicates which server will receive the request.
# 2. The HTTP server processes the HTTP request. This may entail passing the request to some web application, which creates a HTTP response.
# 3. The response gets sent back to the client.
# 4. The client processes the response.
#
# How does the server know what the request is asking for? This is specified by the URL, a special kind of path that specifies where a resource can be found on the web.
#
# ![URL](./assets/http1-url-structure.png)

# %% [markdown]
# <a name="demo-http"></a>
# # <font style = 'color:blue'> Demo: HTTP </font>
#
# ---
#
# Let's explore HTTP resources. We'll start by looking at HTTP requests and responses using the Chrome Inspector.
#
# ![HTTP Request and Response](./assets/http_request_response.jpeg "HTTP Request and Response")
#
# * In Chrome, open up Chrome Inspector (*command + option + 'i', or ctrl + click and select 'inspect element'*).

# %% [markdown]
# * Select the Network tab. It should look something like this:
#
# ![Chrome Inspector](./assets/chrome_inspector.png)

# %% [markdown]
# * Next, go to the URL https://generalassemb.ly/
#
# You should be able to see a few HTTP requests and responses in the Network tab. For each request, you'll see a **Name**, **Initiator**, **Status**, **Type**, and **Size**, along with info about how long it took to get each of these resources.
#   * Most of this information comes from the HTTP Request and Response.
#   * Some HTTP requests are for CSS, JavaScript and images that are referenced by the HTML.
#   * Click on an item in the Name column. Select the Headers tab. Headers are meta-data properties of an HTTP request or response, separate from the body of the message.

# %% [markdown]
# <a id='http-request'></a>
# ## HTTP Request
#
# ---
#
# First, notice that every HTTP request is ultimately plain text -- it is human-readable! This is convenient, but it makes requests larger.
#
# The first word in the request line, _GET_, is the **HTTP method**.
#
# ![HTTP Request](./assets/http_request.jpeg "HTTP Request")

# %% [markdown]
# <a id='request-methods'></a>
# ### HTTP Request methods:
#
# * **`GET`** => Retrieve a resource.
# * **`POST`** => Create a resource.
# * **`PATCH`** (_or **`PUT`**, but **`PATCH`** is recommended_) => Update an existing resource.
# * **`DELETE`** => Delete a resource.
# * **`HEAD`** => Retrieve the headers for a resource.
#
# Of these, **`GET`** and **`POST`** are the most widely used.

# %% [markdown]
# <a id='request-structure'></a>
# ### HTTP Request structure:
#
# ```
# [http request method] [URL] [http version]
# [list of headers]
#
# [request body]
# ```
#
# *Notice that the request header is separated from the request body by a new line.*

# %% [markdown]
# **HTTP Request Method Example: (No Body)**
#
#     GET http://vermonster.com HTTP/1.1
#     Accept:text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8
#     Accept-Encoding:gzip,deflate,sdch
#     Accept-Language:en-US,en;q=0.8
#     Connection:keep-alive
#     Host:vermonster.com
#     User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)
#     AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1659.2 Safari/537.36

# %% [markdown]
# <a id='http-response'></a>
# ## HTTP Response
#
# ---
#
# ![HTTP Response](./assets/http_response.jpeg "HTTP Response")
#
# When a client sends a request, the server sends back a response; the standard format for this response is:
#
# ```
# [http version] [status] [reason]
# [list of headers]
#
# [response body] # typically HTML, JSON, ...
# ```

# %% [markdown]
# <a id='response-types'></a>
# ### Response types overview
#
# > Check these out when you have time -- at least be aware that there is an expected pattern to these codes:
#
# **[Status codes](http://en.wikipedia.org/wiki/List_of_HTTP_status_codes)** have standard meanings; here are a few.
#
# |Code|Reason|
# |:---|:-----|
# |200| OK
# |301| Moved Permanently
# |302| Moved Temporarily
# |307| Temporary Redirect
# |400| Bad Request
# |403| Forbidden
# |404| Not Found
# |500| Internal Server Error

# %% [markdown]
# <a name="json"></a>
# # <font style = 'color:blue'> JSON </font>
#
# ---
#
# JSON is short for _JavaScript Object Notation_, and is a way to store information in an organized, easy-to-access manner. In a nutshell, it gives us a human-readable collection of data that we can access in a really logical manner.
#
# It is very important to realize that JSON is just plain text that you can edit in a text editor. It is called JSON because a JSON string is valid JavaScript code. Because of this, JSON has become very popular with JavaScript programmers for talking with APIs.
#
# **JSON is built on two structures:**
# * A collection of name/value pairs. In various languages, this is realized as an object, record, structure, dictionary, hash table, keyed list, or associative array.
# * An ordered list of values. In most languages, this is realized as an array, vector, list, or sequence.
#
# These are universal data structures. Virtually all modern programming languages support them in one form or another. It makes sense that a data format that is interchangeable with programming languages also be based on these structures.

# %% [markdown]
# ### JSON objects
#
# An object is an unordered set of name/value pairs, like python dictionaries. An object begins with `{` (left brace) and ends with `}` (right brace). Each name is followed by `:` (colon) and the name/value pairs are separated by `,` (comma).
#
# The syntax is as follows:
#
# ```
# { string : value, .......}
# ```
# like:
# ```
# {"count": 1, ...}
# ```
# _Seems an awful lot like a Python dictionary._

# %% [markdown]
# <a name="guided-practice"></a>
# # <font style = 'color:blue'> Pulling data from APIs </font>
#
# ---
#
# Recall that APIs are methods and data formats to tell people how to "talk" to a system. We will walk through a couple of examples.

# %% [markdown]
# <a id='ex1-star-wars'></a>
# ### Example 1: Star Wars
#
# The Star Wars API (SWAPI) is a large collection of data about Star Wars. It can be browsed at the address: https://swapi.dev/.
#
# What if we wanted to programatically access the data in SWAPI? Unless we are employees of the site, we probably don't have direct access to their internal database. So, we cannot perform SQL queries on their data.
#
# We could use scraping to retrieve data from the web page. In some cases (particularly if they do not have a public API), we will have to do exactly that.
#
# > *Note: check the "Terms of Service" before you scrape a website. Scraping could infringe their terms of service.*
#
# In other cases, the website offers a way to programatically access data from their database -- often, as an API.

# %% [markdown]
# **Let's try for example to retrieve the data about the "Obi-Wan Kenobi".**
#
# Referencing the [SWAPI Documentation](http://swapi.co/documentation), lets create a query to search for characters with "obi" in their name.
#
# **In a browser, paste:**
#
#     https://swapi.dev/api/people/?format=json&search=obi

# %% [markdown]
# {
#     "count": 1,
#     "next": null,
#     "previous": null,
#     "results": [
#         {
#             "name": "Obi-Wan Kenobi",
#             "height": "182",
#             "mass": "77",
#             "hair_color": "auburn, white",
#             "skin_color": "fair",
#             "eye_color": "blue-gray",
#             "birth_year": "57BBY",
#             "gender": "male",
#             "homeworld": "http://swapi.co/api/planets/20/",
#             "films": [
#                 "http://swapi.co/api/films/2/",
#                 "http://swapi.co/api/films/5/",
#                 "http://swapi.co/api/films/4/",
#                 "http://swapi.co/api/films/6/",
#                 "http://swapi.co/api/films/3/",
#                 "http://swapi.co/api/films/1/"
#             ],
#             "species": ["http://swapi.co/api/species/1/"],
#             "vehicles": ["http://swapi.co/api/vehicles/38/"],
#             "starships": [
#                 "http://swapi.co/api/starships/48/",
#                 "http://swapi.co/api/starships/59/",
#                 "http://swapi.co/api/starships/64/",
#                 "http://swapi.co/api/starships/65/",
#                 "http://swapi.co/api/starships/74/"
#             ],
#             "created": "2014-12-10T16:16:29.192000Z",
#             "edited": "2014-12-20T21:17:50.325000Z",
#             "url": "http://swapi.co/api/people/10/"
#         }
#     ]
# }

# %% [markdown]
# ###  What Just Happened?

# %% [markdown]
# We requested a url, which responded with JSON.
#
# SWAPI has a GUI-based response as well which is the default.
#
# https://swapi.dev/api/people/?search=obi

# %% [markdown]
# <a id='submit'></a>
# ### Try submitting a couple more queries to familiarize with the API.
#
# - You can also query an API from the command line using the app `curl`. Try typing:
#
#     `curl https://swapi.dev/api/people/13?format=json`

# %% [markdown]
# ```javascript
# {"name":"Chewbacca",
#     "height":"228",
#         "mass":"112",
#             "hair_color":"brown",
#                 "skin_color":"unknown",
#                 "eye_color":"blue",
#                 "birth_year":"200BBY",
#                 "gender":"male",
#         "homeworld":"https://swapi.dev/api/planets/14/",
#         "films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],
#             "species":["https://swapi.dev/api/species/3/"],
#                 "vehicles":["https://swapi.dev/api/vehicles/19/"],"starships":["https://swapi.dev/api/starships/10/","https://swapi.dev/api/starships/22/"],
#                "created":"2014-12-10T16:42:45.066000Z","edited":"2014-12-20T21:17:50.332000Z","url":"https://swapi.dev/api/people/13/"}
# ```

# %%
# Request example for the SWAPI example
import pandas as pd
import requests

result = requests.get("http://swapi.dev/api/people/10")
df = pd.DataFrame([result.json()])
df
# Out:
#              name height mass     hair_color skin_color  eye_color birth_year  \
# 0  Obi-Wan Kenobi    182   77  auburn, white       fair  blue-gray      57BBY
#
#   gender                          homeworld  \
# 0   male  https://swapi.dev/api/planets/20/
#
#                                                films species  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...      []
#
#                                vehicles  \
# 0  [https://swapi.dev/api/vehicles/38/]
#
#                                            starships  \
# 0  [https://swapi.dev/api/starships/48/, https://...
#
#                        created                       edited  \
# 0  2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
#
#                                 url
# 0  https://swapi.dev/api/people/10/

# %% [markdown]
# <a id='ex2-geocode'></a>
# ### Example 2: COVID data
#
# In this example, we're requesting data from this API: https://covid19api.com/
#
# Take a few moments to read through some of the information on this site and figure out:
#
# * Where this API gets its data from (and whether it's a reputable source)
# * How we can access the documentation that tells us how the API works
# * Whether the API is free
#
#
# Let's start by importing the [**requests**](https://docs.python-requests.org/en/latest/) library, which we'll be using to make API requests.

# %% [markdown]
# Let's make a request to the coronavirus API and view the resulting JSON. The first thing we do is make a GET request. This is really simple!

# %%
covid_request = requests.get('https://api.covid19api.com/summary')

# %% [markdown]
# The thing we get back from a GET request is a request object.

# %%
type(covid_request)
# Out:
# requests.models.Response

# %% [markdown]
# This is an object that has a few different bits of information bundled up inside it, all of which have been sent back to us by the servers, including...
#
# The status code, which tells us whether the request was successful or not. A status code of 200 means the request was a success, whereas a status code of 400 means there was an error. You might remember seeing 404: error messages in your browser when you try to load a webpage that doesn't exist- that's also an example of a status code!
#
# We can check the status code like this:

# %%
covid_request.status_code
# Out:
# 200

# %% [markdown]
# We can also access the JSON that's returned by the API; this is also bundled up inside our request object.

# %%
covid_request.json()
# Out:
# {'ID': 'ab968040-c55a-472a-9678-89c13c8de8cc',
#  'Message': '',
#  'Global': {'NewConfirmed': 376409,
#   'TotalConfirmed': 470110971,
#   'NewDeaths': 1443,
#   'TotalDeaths': 6072950,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-03-21T17:45:10.368Z'},
#  'Countries': [{'ID': '344cb251-9ccd-485c-b690-0d16b03e2a9c',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 177093,
#    'NewDeaths': 0,
#    'TotalDeaths': 7654,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '44aa7abc-88ff-41e5-8097-4b3b506e4fd0',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 273088,
#    'NewDeaths': 0,
#    'TotalDeaths': 3487,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6f2c4055-d484-4a6a-a8e0-41489da60bb1',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 265550,
#    'NewDeaths': 0,
#    'TotalDeaths': 6871,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8e3715c8-38e5-48ad-b9b0-0de70143bc34',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39234,
#    'NewDeaths': 0,
#    'TotalDeaths': 153,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2d9f66e3-90a5-46f3-b47c-9694585c63dd',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 99003,
#    'NewDeaths': 0,
#    'TotalDeaths': 1900,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'aedf070a-7384-4305-9ab6-151942cb3e3c',
#    'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fd9e93a4-8a31-4167-8c86-2921bf46de04',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7473,
#    'NewDeaths': 0,
#    'TotalDeaths': 135,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'da04e629-4e5f-4b3d-9735-bd0e7e23cfb8',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9007753,
#    'NewDeaths': 0,
#    'TotalDeaths': 127494,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '08fd5c00-1a17-4b8e-a1ea-43a3667d9529',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 422307,
#    'NewDeaths': 0,
#    'TotalDeaths': 8595,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'aefe7025-53e4-435d-864e-c937dcd6be93',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 43230,
#    'TotalConfirmed': 3943368,
#    'NewDeaths': 11,
#    'TotalDeaths': 5736,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5cc940ad-00dc-43b2-b8bb-d1f934a36bc0',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3466203,
#    'NewDeaths': 0,
#    'TotalDeaths': 15409,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '042a53bd-ece1-432b-bdb2-7f51556fd6f4',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 791482,
#    'NewDeaths': 0,
#    'TotalDeaths': 9656,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'af1b50b7-7e56-46bd-aabc-fcefa7e4f5f5',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33221,
#    'NewDeaths': 0,
#    'TotalDeaths': 787,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e2ebe4a1-fc3f-4f1c-8cc8-067a903b61b0',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 544851,
#    'NewDeaths': 0,
#    'TotalDeaths': 1465,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7d06570c-cdb0-4fab-a390-89ad9c26d821',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1950609,
#    'NewDeaths': 0,
#    'TotalDeaths': 29117,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ce16c5de-ba7b-44d7-bf58-a5ca995a0b01',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57733,
#    'NewDeaths': 0,
#    'TotalDeaths': 329,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3a1df28e-058b-4477-880c-cc16d0e3c6c2',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 951081,
#    'NewDeaths': 0,
#    'TotalDeaths': 6722,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'dd149396-ab46-4ae6-8423-2d2393583274',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3707561,
#    'NewDeaths': 0,
#    'TotalDeaths': 30529,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c410bbc7-2f87-470e-b78f-485dd4d027ed',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57143,
#    'NewDeaths': 0,
#    'TotalDeaths': 654,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd03db1ea-10ff-4b5d-80a8-b88ca3dd72a6',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26952,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8f18afea-6e96-45f8-bcad-0b6dafdd15f7',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22004,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a5df2478-dbd7-4b10-99fd-083d72b7545a',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 899697,
#    'NewDeaths': 0,
#    'TotalDeaths': 21482,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4b7da7b0-0d51-4eb9-9e39-dae72e143113',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 373985,
#    'NewDeaths': 0,
#    'TotalDeaths': 15664,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3792952c-dfd5-4fc2-bfa9-9ed6eb687c9f',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 263950,
#    'NewDeaths': 0,
#    'TotalDeaths': 2619,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0067a372-2a6a-4afe-b241-be8c814ecfeb',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 13379,
#    'TotalConfirmed': 29637814,
#    'NewDeaths': 106,
#    'TotalDeaths': 657495,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '46f99360-217d-4ede-a5f7-fe7ff63e2f21',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 124716,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ec9361c9-4bd9-4ca5-ae8c-fb9f19b9bb61',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1124186,
#    'NewDeaths': 0,
#    'TotalDeaths': 36282,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a23c99ae-9cee-4282-acd8-871b6964e690',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20813,
#    'NewDeaths': 0,
#    'TotalDeaths': 379,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '78d4e180-c1cc-4866-80eb-88734298a280',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 38308,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ed586f3b-23c9-44a7-8b56-60a2b56bf671',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 134986,
#    'NewDeaths': 0,
#    'TotalDeaths': 3051,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bf60225d-cb4d-4246-bf61-c7f638f0df59',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 119544,
#    'NewDeaths': 0,
#    'TotalDeaths': 1927,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '17a77f82-a0ab-4adc-8484-31ebf5567ea1',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 2253,
#    'TotalConfirmed': 2870653,
#    'NewDeaths': 11,
#    'TotalDeaths': 33191,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '75ba0c37-76c6-44a7-9592-a3d6f0965ffa',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55925,
#    'NewDeaths': 0,
#    'TotalDeaths': 401,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4e91f491-7ee3-4b97-bb90-61ec6b793239',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14649,
#    'NewDeaths': 0,
#    'TotalDeaths': 113,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3c4f9c50-7c29-4123-98ca-ac7237896d4f',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7269,
#    'NewDeaths': 0,
#    'TotalDeaths': 190,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5dd819fd-63f5-4fee-b906-c603dc865b85',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 11297,
#    'TotalConfirmed': 3392978,
#    'NewDeaths': 78,
#    'TotalDeaths': 44518,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7909607f-371f-4545-aa82-1078aa0a1ead',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 14634,
#    'TotalConfirmed': 1178456,
#    'NewDeaths': 246,
#    'TotalDeaths': 10534,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ccc6e5b0-0dfe-490b-9b64-ea7d105a548c',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 542,
#    'TotalConfirmed': 6081131,
#    'NewDeaths': 18,
#    'TotalDeaths': 139452,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a1502c2b-155e-410f-8f1b-95bf6a059a3c',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8076,
#    'NewDeaths': 0,
#    'TotalDeaths': 160,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a193ee24-faca-43c0-be40-e88e0a48e3bd',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24059,
#    'NewDeaths': 0,
#    'TotalDeaths': 383,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c3d44afd-72a3-43dd-8225-cdd55557d130',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 86461,
#    'NewDeaths': 0,
#    'TotalDeaths': 1335,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4aa8a1aa-d0d9-471b-8c88-c5a860b240ff',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 829400,
#    'NewDeaths': 0,
#    'TotalDeaths': 8226,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b2b5abbb-c19c-40e2-9e0e-00b100c25723',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1084012,
#    'NewDeaths': 0,
#    'TotalDeaths': 15435,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bfa05d33-cbcb-4004-a35b-e57b70d77420',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1081472,
#    'NewDeaths': 0,
#    'TotalDeaths': 8506,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '905ff634-b53a-4f76-adcd-5e688431e91b',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 377356,
#    'NewDeaths': 0,
#    'TotalDeaths': 919,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '81c00be7-2a97-4550-b1dc-28419009fd90',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3737891,
#    'NewDeaths': 0,
#    'TotalDeaths': 39359,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '792e2493-4c94-4df2-82cb-ba1ef28d01ae',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 81655,
#    'NewDeaths': 0,
#    'TotalDeaths': 796,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2070c48b-d612-45f2-933d-d28853ee36ce',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3051491,
#    'NewDeaths': 0,
#    'TotalDeaths': 5450,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b4f5bb50-a0b8-4d9d-8109-d408d9b3bf40',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15573,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '88764c39-2395-4005-86ae-983df469e6b0',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11724,
#    'NewDeaths': 0,
#    'TotalDeaths': 62,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0e91ac9e-aeec-4c6f-b210-3266d13bd6fe',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 577317,
#    'NewDeaths': 0,
#    'TotalDeaths': 4375,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '748836d7-5837-493e-96c4-e913c298db7c',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 853850,
#    'NewDeaths': 0,
#    'TotalDeaths': 35410,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1fa0f635-add5-4437-acd5-5698484c579d',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 495373,
#    'NewDeaths': 0,
#    'TotalDeaths': 24277,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8f35c272-8125-4d45-9f66-1608806d3804',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 161052,
#    'NewDeaths': 0,
#    'TotalDeaths': 4109,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '55b61212-7a74-4731-8402-d08e22db35f1',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15899,
#    'NewDeaths': 0,
#    'TotalDeaths': 183,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '62baba9f-0790-4be7-b293-5adcce2f4d65',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9723,
#    'NewDeaths': 0,
#    'TotalDeaths': 103,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c115ab18-9aaa-4123-afad-328cd65c25f8',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 542386,
#    'NewDeaths': 0,
#    'TotalDeaths': 2392,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'def1b2ea-c349-4222-a9e9-b17a8f7f6951',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 469455,
#    'NewDeaths': 0,
#    'TotalDeaths': 7489,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3c842554-3674-48ef-acc3-50332ad4fdea',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64221,
#    'NewDeaths': 0,
#    'TotalDeaths': 834,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b6215307-c645-48bf-bbd9-0246e7c90a5b',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 786312,
#    'NewDeaths': 0,
#    'TotalDeaths': 2783,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1470b3c8-ae1e-4ba9-b686-4398e59afd8e',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24323239,
#    'NewDeaths': 0,
#    'TotalDeaths': 141961,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b2d46714-afae-495b-ad65-5e342da19a7a',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 47570,
#    'NewDeaths': 0,
#    'TotalDeaths': 303,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '104acaa9-08e4-4416-ac21-88f9fdce88e6',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11978,
#    'NewDeaths': 0,
#    'TotalDeaths': 365,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bce8d2e9-1acb-4549-b101-a0b61aa97be5',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1641874,
#    'NewDeaths': 0,
#    'TotalDeaths': 16663,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ea7bc688-945e-414e-8462-78c77296ffbe',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 92316,
#    'TotalConfirmed': 18809998,
#    'NewDeaths': 13,
#    'TotalDeaths': 126933,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '79b1e88e-4def-475a-b24c-7f7ed1e7a2fd',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 160819,
#    'NewDeaths': 0,
#    'TotalDeaths': 1445,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '62f51df3-3658-4832-9fac-ff343366f1f9',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2788654,
#    'NewDeaths': 0,
#    'TotalDeaths': 26937,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3a7a1657-c781-4e74-bcb0-3bbf19423dcb',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13936,
#    'NewDeaths': 0,
#    'TotalDeaths': 217,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c44c1fca-7450-4973-8168-c00afcce45a8',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 816136,
#    'NewDeaths': 0,
#    'TotalDeaths': 17238,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1d435ead-bd53-4fd3-a038-723456f5df5d',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36435,
#    'NewDeaths': 0,
#    'TotalDeaths': 440,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '284d6f48-8b0c-4f91-92fe-92e1acc5a26b',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8113,
#    'NewDeaths': 0,
#    'TotalDeaths': 169,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bcac3aba-2a3f-44d1-b3fc-b0ee695ce5b7',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63194,
#    'NewDeaths': 0,
#    'TotalDeaths': 1226,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e1b3d7fe-d685-4844-97bc-7d734252ac80',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30478,
#    'NewDeaths': 0,
#    'TotalDeaths': 827,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e3e28432-3b8d-4d57-ba5f-6624514e37ef',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e06021f1-7cb5-48e3-8bf5-dcd61e8e293e',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 418300,
#    'NewDeaths': 0,
#    'TotalDeaths': 10857,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '041ecea3-425a-405a-a228-f16be65f720e',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1824089,
#    'NewDeaths': 0,
#    'TotalDeaths': 44961,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '571c339d-4e76-487a-bf5f-122f735fa008',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 170806,
#    'NewDeaths': 0,
#    'TotalDeaths': 91,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '69e2803b-dfce-419d-adee-04a40d755021',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 1549,
#    'TotalConfirmed': 43009390,
#    'NewDeaths': 31,
#    'TotalDeaths': 516510,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '15b68280-93ec-44e1-9414-3391d32522e9',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5962483,
#    'NewDeaths': 0,
#    'TotalDeaths': 153738,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '312c2530-f369-4c7a-bcc7-eb759e1f69a9',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7141033,
#    'NewDeaths': 0,
#    'TotalDeaths': 139610,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '393cf270-482d-4662-af68-74ab9373a668',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2316044,
#    'NewDeaths': 0,
#    'TotalDeaths': 25129,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '018dc168-7d3b-460e-b575-ea8cf6387e1f',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1365467,
#    'NewDeaths': 0,
#    'TotalDeaths': 6638,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5702cbcf-1ba9-4349-a652-4a7057186f3d',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3772751,
#    'NewDeaths': 0,
#    'TotalDeaths': 10431,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e01d2939-8983-46ae-bbdc-ef0e15a67acd',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 61564,
#    'TotalConfirmed': 13861743,
#    'NewDeaths': 93,
#    'TotalDeaths': 157785,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e05e8106-58bd-4db1-b733-d8e689241084',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 128539,
#    'NewDeaths': 0,
#    'TotalDeaths': 2867,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8843e23f-dc24-43d4-b6aa-4e5d8833c6ab',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 39560,
#    'TotalConfirmed': 6100331,
#    'NewDeaths': 66,
#    'TotalDeaths': 27122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '9fee6651-609e-444b-9612-cf7bc066bbc5',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1680179,
#    'NewDeaths': 0,
#    'TotalDeaths': 13959,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4e74d647-9743-4403-a494-30f60a8d4ea2',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1393427,
#    'NewDeaths': 0,
#    'TotalDeaths': 19001,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ef5561cf-cc8c-42ab-891e-18d3b925f343',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 323281,
#    'NewDeaths': 0,
#    'TotalDeaths': 5647,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '397687b3-48f9-424a-a8bd-a0ca77eff299',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3049,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'aefafec2-5a7b-45b1-9c6f-3486cc630637',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9582815,
#    'NewDeaths': 0,
#    'TotalDeaths': 12757,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4e18eb66-cf85-4262-a256-45b9126ca678',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 627342,
#    'NewDeaths': 0,
#    'TotalDeaths': 2553,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '678a8b49-8a1c-40b1-8c17-e7cdebc471b0',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 200818,
#    'NewDeaths': 0,
#    'TotalDeaths': 2980,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '692e9630-4a73-462e-a5b7-8bbe19ebb04e',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 152957,
#    'NewDeaths': 0,
#    'TotalDeaths': 645,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '95855b76-8066-4dde-b295-94b5b6edbfbc',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 771038,
#    'NewDeaths': 0,
#    'TotalDeaths': 5511,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fb2d63b1-a7a9-406b-902b-43ca7265a662',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1088196,
#    'NewDeaths': 0,
#    'TotalDeaths': 10248,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a5b9d587-72c2-4f1f-8be8-a2a89aab7977',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32775,
#    'NewDeaths': 0,
#    'TotalDeaths': 697,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ee074c4e-30ef-4755-b0c3-f220fd6d8716',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7397,
#    'NewDeaths': 0,
#    'TotalDeaths': 294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '01601103-a1c7-4ae1-b49e-3a2f7c7fb603',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 501015,
#    'NewDeaths': 0,
#    'TotalDeaths': 6374,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e179e3fa-b368-4c30-a8eb-381f736942ca',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15312,
#    'NewDeaths': 0,
#    'TotalDeaths': 81,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd4c86752-6dbb-45e6-a8e3-a54c46b0320b',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 992101,
#    'NewDeaths': 0,
#    'TotalDeaths': 8728,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0c18cf37-8ff9-43c2-a1a7-c906b4c3e37c',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 199202,
#    'NewDeaths': 0,
#    'TotalDeaths': 1010,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '711e6f4c-a6c4-429f-a226-c5bf25c86106',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 303354,
#    'NewDeaths': 0,
#    'TotalDeaths': 9180,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '04323646-0d9c-4f19-b020-93bb2eed8229',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63928,
#    'NewDeaths': 0,
#    'TotalDeaths': 1380,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'f41c6db3-94dd-4e64-baee-cc89edde6069',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 85561,
#    'NewDeaths': 0,
#    'TotalDeaths': 2626,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e6b878f1-f1d3-475e-9767-2bc75ddebc9f',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 19105,
#    'TotalConfirmed': 3993124,
#    'NewDeaths': 71,
#    'TotalDeaths': 34400,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fd42e165-d826-4ec0-8a5f-242fc73f881f',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 174658,
#    'NewDeaths': 0,
#    'TotalDeaths': 297,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fd0a925b-a922-4086-899b-67acd363bd05',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30453,
#    'NewDeaths': 0,
#    'TotalDeaths': 727,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fde252ed-e5e4-4237-9722-8e08807e0982',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 74518,
#    'NewDeaths': 0,
#    'TotalDeaths': 622,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '9abf2bf7-2926-43d4-a08a-2803e2f8b05c',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c518dba7-b08c-4fd9-a22d-a2e113334559',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 58662,
#    'NewDeaths': 0,
#    'TotalDeaths': 981,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3e729da9-03af-4886-8980-371323aacceb',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 192558,
#    'NewDeaths': 0,
#    'TotalDeaths': 934,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3fca442c-fbb6-4ad9-9b39-9bd19e29a667',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 4114,
#    'TotalConfirmed': 5633928,
#    'NewDeaths': 141,
#    'TotalDeaths': 322072,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd6ddc31b-c38d-422c-a2a6-1b893e56a134',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3cd815b2-c196-4bc0-bece-c5b31d51ef05',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 510460,
#    'NewDeaths': 0,
#    'TotalDeaths': 11389,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2715d72f-2ef3-402d-b1ae-fde84df54021',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10127,
#    'NewDeaths': 0,
#    'TotalDeaths': 54,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'da6892cb-0455-49f4-ab94-9af0c39fc223',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 916723,
#    'NewDeaths': 0,
#    'TotalDeaths': 2177,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e031a9bf-dc7a-4a21-a3b9-7f339401bb85',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 232193,
#    'NewDeaths': 0,
#    'TotalDeaths': 2696,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5e6a0bf1-483c-45f7-9ae4-3d042fff7208',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1162497,
#    'NewDeaths': 0,
#    'TotalDeaths': 16052,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a780795c-f0ab-4160-95f6-4ea89862bb04',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 225210,
#    'NewDeaths': 0,
#    'TotalDeaths': 2200,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b1d25af1-2118-4919-a4bb-b4b7368272cf',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 608990,
#    'NewDeaths': 0,
#    'TotalDeaths': 19425,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c468927a-652d-4121-a1a3-a860db12950f',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 157523,
#    'NewDeaths': 0,
#    'TotalDeaths': 4016,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2eee7629-9166-4a9d-b052-b501b7305a13',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 978155,
#    'NewDeaths': 0,
#    'TotalDeaths': 11950,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'cd99ebaf-6233-4748-8d52-6698f7092487',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 34823,
#    'TotalConfirmed': 7595517,
#    'NewDeaths': 8,
#    'TotalDeaths': 21814,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8c9b6fb3-f99e-4485-bb06-9e83db91f4fa',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 498474,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0cd4eb85-b400-4f1c-8178-5b16613c92f9',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18290,
#    'NewDeaths': 0,
#    'TotalDeaths': 228,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0c1ec0bc-8845-4731-95ff-b86f2e4804ef',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8788,
#    'NewDeaths': 0,
#    'TotalDeaths': 308,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '396da93d-9d20-4a51-96b0-de6259f428ce',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 255103,
#    'NewDeaths': 0,
#    'TotalDeaths': 3142,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b6a36db4-154d-44c8-95de-2101b59c70c2',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1379467,
#    'NewDeaths': 0,
#    'TotalDeaths': 2169,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd84d00ff-a075-48fb-9031-9731dbc73f35',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 387505,
#    'NewDeaths': 0,
#    'TotalDeaths': 4250,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b700e320-a754-447b-a923-a3cc4ba312d8',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 303,
#    'TotalConfirmed': 1522191,
#    'NewDeaths': 2,
#    'TotalDeaths': 30331,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c7ed2012-1510-468c-aaf3-2953c0503da1',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3945,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd7a2e4fc-33cc-4be5-b2af-7cbe81aa65b3',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 654380,
#    'NewDeaths': 0,
#    'TotalDeaths': 5628,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5e7a76f2-ab9c-42bc-b8f6-9abae86d1159',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 761508,
#    'NewDeaths': 0,
#    'TotalDeaths': 8156,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '87017a96-dd39-4613-a9ca-628f5f61692d',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 41533,
#    'NewDeaths': 0,
#    'TotalDeaths': 639,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ea91a4a7-3fec-4403-944d-1b582adc4905',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 647099,
#    'NewDeaths': 0,
#    'TotalDeaths': 18586,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6be5416e-5e31-481f-9804-da5197540ec9',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 604,
#    'TotalConfirmed': 3541397,
#    'NewDeaths': 51,
#    'TotalDeaths': 211865,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'f0183bea-7919-4024-bfbc-260c76e651c0',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3674286,
#    'NewDeaths': 0,
#    'TotalDeaths': 58263,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6746bf07-a020-4931-b579-e38f26664219',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5891140,
#    'NewDeaths': 0,
#    'TotalDeaths': 114218,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '422ad149-e3fc-4b1b-a326-607131bdc409',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3458727,
#    'NewDeaths': 0,
#    'TotalDeaths': 21408,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '58866fef-1c9b-4061-b189-ce04f2a40931',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 359956,
#    'NewDeaths': 0,
#    'TotalDeaths': 677,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '74531f1d-8164-4a66-85ae-18d90c6f4d01',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 227124,
#    'NewDeaths': 0,
#    'TotalDeaths': 3127,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2f12ce2c-0fe6-4b03-8dd6-43aec0c65f05',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2816039,
#    'NewDeaths': 0,
#    'TotalDeaths': 64685,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b4b9f384-de80-4577-a1f4-f3b6328381ef',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 30513,
#    'TotalConfirmed': 17327694,
#    'NewDeaths': 422,
#    'TotalDeaths': 357234,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'feaae5f8-a6c7-4f6b-8100-8bf439e063be',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 129647,
#    'NewDeaths': 0,
#    'TotalDeaths': 1459,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a729514a-1af1-4f08-90e1-f5142904b924',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5548,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '9e3f7324-d4b6-441e-a662-aa141efd89d9',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22884,
#    'NewDeaths': 0,
#    'TotalDeaths': 365,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b0c14335-b188-4a61-b52c-6fd5677e85ce',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8326,
#    'NewDeaths': 0,
#    'TotalDeaths': 106,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2f3d46c7-d8be-43b9-9532-471fa44f91ef',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 111,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '64ce2a10-ba77-4171-b068-b3b1b4b6d2b5',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14870,
#    'NewDeaths': 0,
#    'TotalDeaths': 112,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8774f467-a342-44ef-bfd9-f9d346fd6c7c',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5941,
#    'NewDeaths': 0,
#    'TotalDeaths': 73,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6585d044-5f72-402f-87d6-ce4a866149a2',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 749597,
#    'NewDeaths': 0,
#    'TotalDeaths': 9028,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '73483fea-a993-4791-b194-0410b285aa1b',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 85827,
#    'NewDeaths': 0,
#    'TotalDeaths': 1964,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7dae0a5c-20d1-4e4b-aea2-cf356c0a2f12',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1955280,
#    'NewDeaths': 0,
#    'TotalDeaths': 15687,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '014c31ac-5a98-4259-a574-9470f03fba75',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39797,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e9ccdc79-ac0b-47aa-a067-e87ba69519bc',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7674,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4deb5cb7-d625-4c54-a51d-c666589b93bf',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1015017,
#    'NewDeaths': 0,
#    'TotalDeaths': 1198,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd6368662-1edb-436c-9d2f-1d2a5932039a',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2351701,
#    'NewDeaths': 0,
#    'TotalDeaths': 19110,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd98e2677-8f70-4314-b4fd-d52830e9c7d8',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 936847,
#    'NewDeaths': 0,
#    'TotalDeaths': 6442,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ca9631dd-1c4a-4eaf-b6c4-cdf3ec16b287',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9851,
#    'NewDeaths': 0,
#    'TotalDeaths': 127,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '64374a49-4707-4ea7-acd8-928919761bd6',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26410,
#    'NewDeaths': 0,
#    'TotalDeaths': 1361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2c8534b7-0f27-414f-a5a2-910645f7aa2c',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3704218,
#    'NewDeaths': 0,
#    'TotalDeaths': 99881,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c2d37705-ceab-432b-a7ca-6bdde27d091a',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17093,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '07c62d1c-0d81-45c3-b6df-54ae7969d516',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11324637,
#    'NewDeaths': 0,
#    'TotalDeaths': 101703,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'cb3f6d56-f5b0-4493-8566-e54da3feebc0',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 658197,
#    'NewDeaths': 0,
#    'TotalDeaths': 16431,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3766a41b-4160-448c-8704-2b99b41c32b6',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 61775,
#    'NewDeaths': 0,
#    'TotalDeaths': 4888,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e73e6a6d-f79d-492b-bda6-edb8b64600de',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 78946,
#    'NewDeaths': 0,
#    'TotalDeaths': 1323,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '08cc074b-92d7-498b-98d8-f71720c25b54',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 69552,
#    'NewDeaths': 0,
#    'TotalDeaths': 1392,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7b4e5912-ea22-490c-b053-726c7be73abf',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2475687,
#    'NewDeaths': 0,
#    'TotalDeaths': 18053,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'caa010f0-a388-4ca0-8c77-7e793ad0dc74',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3268953,
#    'NewDeaths': 0,
#    'TotalDeaths': 13423,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '06dc162d-6275-4ab2-8e7d-2cc89cb4d4d7',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55558,
#    'NewDeaths': 0,
#    'TotalDeaths': 3127,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '10f3a19c-212f-48ee-b058-a0bb4879e595',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21905,
#    'NewDeaths': 0,
#    'TotalDeaths': 853,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2f534467-de2d-417e-a88c-142a2c61740f',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17786,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6b3e1ed3-8686-4804-aecf-df161fc61015',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33773,
#    'NewDeaths': 0,
#    'TotalDeaths': 800,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a4f04a69-f971-42cd-8ae9-347a45e997fa',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3377410,
#    'NewDeaths': 0,
#    'TotalDeaths': 24334,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '935ad0d2-0c75-4088-8c7a-f9be73a90599',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22801,
#    'NewDeaths': 0,
#    'TotalDeaths': 129,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '14c6bfca-f870-4360-bd43-f23e3c9b710e',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36878,
#    'NewDeaths': 0,
#    'TotalDeaths': 272,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '190a3266-d028-43e5-9002-612dedca831e',
#    'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3232,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8e299708-96fb-41eb-8271-8bb7461645cc',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 135097,
#    'NewDeaths': 0,
#    'TotalDeaths': 3712,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3b9faebe-9e3e-4786-bdaa-28837000d891',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1029762,
#    'NewDeaths': 0,
#    'TotalDeaths': 28065,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3cf28f82-25a3-4fea-99de-9ea8a609af38',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14693917,
#    'NewDeaths': 0,
#    'TotalDeaths': 97267,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '91e6bccc-887f-4c21-bc4d-ab52bfe88bf1',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 163688,
#    'NewDeaths': 0,
#    'TotalDeaths': 3595,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a92a109d-a05d-4f9f-b3e3-c82c24f621b9',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5040518,
#    'NewDeaths': 0,
#    'TotalDeaths': 112459,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '634c346d-354d-417c-8f6e-a600b006fd2c',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 887732,
#    'NewDeaths': 0,
#    'TotalDeaths': 2302,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fbb3f957-e451-473c-9c30-668cc8950e42',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20243940,
#    'NewDeaths': 0,
#    'TotalDeaths': 164099,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd0ea6200-b54d-479a-842a-6ba4f510a175',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 6623,
#    'TotalConfirmed': 79734788,
#    'NewDeaths': 75,
#    'TotalDeaths': 971162,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1c0fe4df-f6c1-4fbc-a8e2-725e19fc6d34',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 875313,
#    'NewDeaths': 0,
#    'TotalDeaths': 7138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1ed972db-e7cf-43a9-afd4-c3827be810a1',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 237476,
#    'NewDeaths': 0,
#    'TotalDeaths': 1637,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '040705d7-a82f-4945-ac4d-ccb0b848a561',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 753,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '051587ff-757c-4da8-ae0f-7f9c74960c8e',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 519670,
#    'NewDeaths': 0,
#    'TotalDeaths': 5668,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5c719820-718a-4482-bb69-99a844c946a8',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7958048,
#    'NewDeaths': 0,
#    'TotalDeaths': 41880,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8afbce96-7ecd-4653-ad37-4a97403467f9',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11801,
#    'NewDeaths': 0,
#    'TotalDeaths': 2140,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6735ae99-f98d-4e3c-ae2f-02083117b452',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 315623,
#    'NewDeaths': 0,
#    'TotalDeaths': 3962,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '75b96d46-88f8-4620-bdf3-1de2e9302a5a',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 244452,
#    'NewDeaths': 0,
#    'TotalDeaths': 5426,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}}],
#  'Date': '2022-03-21T17:45:10.368Z'}

# %% [markdown]
# Let's create a variable that contains the JSON only.

# %%
covid_json = covid_request.json()
covid_json
# Out:
# {'ID': 'ab968040-c55a-472a-9678-89c13c8de8cc',
#  'Message': '',
#  'Global': {'NewConfirmed': 376409,
#   'TotalConfirmed': 470110971,
#   'NewDeaths': 1443,
#   'TotalDeaths': 6072950,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-03-21T17:45:10.368Z'},
#  'Countries': [{'ID': '344cb251-9ccd-485c-b690-0d16b03e2a9c',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 177093,
#    'NewDeaths': 0,
#    'TotalDeaths': 7654,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '44aa7abc-88ff-41e5-8097-4b3b506e4fd0',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 273088,
#    'NewDeaths': 0,
#    'TotalDeaths': 3487,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6f2c4055-d484-4a6a-a8e0-41489da60bb1',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 265550,
#    'NewDeaths': 0,
#    'TotalDeaths': 6871,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8e3715c8-38e5-48ad-b9b0-0de70143bc34',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39234,
#    'NewDeaths': 0,
#    'TotalDeaths': 153,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2d9f66e3-90a5-46f3-b47c-9694585c63dd',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 99003,
#    'NewDeaths': 0,
#    'TotalDeaths': 1900,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'aedf070a-7384-4305-9ab6-151942cb3e3c',
#    'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fd9e93a4-8a31-4167-8c86-2921bf46de04',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7473,
#    'NewDeaths': 0,
#    'TotalDeaths': 135,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'da04e629-4e5f-4b3d-9735-bd0e7e23cfb8',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9007753,
#    'NewDeaths': 0,
#    'TotalDeaths': 127494,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '08fd5c00-1a17-4b8e-a1ea-43a3667d9529',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 422307,
#    'NewDeaths': 0,
#    'TotalDeaths': 8595,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'aefe7025-53e4-435d-864e-c937dcd6be93',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 43230,
#    'TotalConfirmed': 3943368,
#    'NewDeaths': 11,
#    'TotalDeaths': 5736,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5cc940ad-00dc-43b2-b8bb-d1f934a36bc0',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3466203,
#    'NewDeaths': 0,
#    'TotalDeaths': 15409,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '042a53bd-ece1-432b-bdb2-7f51556fd6f4',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 791482,
#    'NewDeaths': 0,
#    'TotalDeaths': 9656,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'af1b50b7-7e56-46bd-aabc-fcefa7e4f5f5',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33221,
#    'NewDeaths': 0,
#    'TotalDeaths': 787,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e2ebe4a1-fc3f-4f1c-8cc8-067a903b61b0',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 544851,
#    'NewDeaths': 0,
#    'TotalDeaths': 1465,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7d06570c-cdb0-4fab-a390-89ad9c26d821',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1950609,
#    'NewDeaths': 0,
#    'TotalDeaths': 29117,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ce16c5de-ba7b-44d7-bf58-a5ca995a0b01',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57733,
#    'NewDeaths': 0,
#    'TotalDeaths': 329,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3a1df28e-058b-4477-880c-cc16d0e3c6c2',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 951081,
#    'NewDeaths': 0,
#    'TotalDeaths': 6722,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'dd149396-ab46-4ae6-8423-2d2393583274',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3707561,
#    'NewDeaths': 0,
#    'TotalDeaths': 30529,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c410bbc7-2f87-470e-b78f-485dd4d027ed',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57143,
#    'NewDeaths': 0,
#    'TotalDeaths': 654,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd03db1ea-10ff-4b5d-80a8-b88ca3dd72a6',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26952,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8f18afea-6e96-45f8-bcad-0b6dafdd15f7',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22004,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a5df2478-dbd7-4b10-99fd-083d72b7545a',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 899697,
#    'NewDeaths': 0,
#    'TotalDeaths': 21482,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4b7da7b0-0d51-4eb9-9e39-dae72e143113',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 373985,
#    'NewDeaths': 0,
#    'TotalDeaths': 15664,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3792952c-dfd5-4fc2-bfa9-9ed6eb687c9f',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 263950,
#    'NewDeaths': 0,
#    'TotalDeaths': 2619,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0067a372-2a6a-4afe-b241-be8c814ecfeb',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 13379,
#    'TotalConfirmed': 29637814,
#    'NewDeaths': 106,
#    'TotalDeaths': 657495,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '46f99360-217d-4ede-a5f7-fe7ff63e2f21',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 124716,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ec9361c9-4bd9-4ca5-ae8c-fb9f19b9bb61',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1124186,
#    'NewDeaths': 0,
#    'TotalDeaths': 36282,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a23c99ae-9cee-4282-acd8-871b6964e690',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20813,
#    'NewDeaths': 0,
#    'TotalDeaths': 379,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '78d4e180-c1cc-4866-80eb-88734298a280',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 38308,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ed586f3b-23c9-44a7-8b56-60a2b56bf671',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 134986,
#    'NewDeaths': 0,
#    'TotalDeaths': 3051,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bf60225d-cb4d-4246-bf61-c7f638f0df59',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 119544,
#    'NewDeaths': 0,
#    'TotalDeaths': 1927,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '17a77f82-a0ab-4adc-8484-31ebf5567ea1',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 2253,
#    'TotalConfirmed': 2870653,
#    'NewDeaths': 11,
#    'TotalDeaths': 33191,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '75ba0c37-76c6-44a7-9592-a3d6f0965ffa',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55925,
#    'NewDeaths': 0,
#    'TotalDeaths': 401,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4e91f491-7ee3-4b97-bb90-61ec6b793239',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14649,
#    'NewDeaths': 0,
#    'TotalDeaths': 113,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3c4f9c50-7c29-4123-98ca-ac7237896d4f',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7269,
#    'NewDeaths': 0,
#    'TotalDeaths': 190,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5dd819fd-63f5-4fee-b906-c603dc865b85',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 11297,
#    'TotalConfirmed': 3392978,
#    'NewDeaths': 78,
#    'TotalDeaths': 44518,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7909607f-371f-4545-aa82-1078aa0a1ead',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 14634,
#    'TotalConfirmed': 1178456,
#    'NewDeaths': 246,
#    'TotalDeaths': 10534,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ccc6e5b0-0dfe-490b-9b64-ea7d105a548c',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 542,
#    'TotalConfirmed': 6081131,
#    'NewDeaths': 18,
#    'TotalDeaths': 139452,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a1502c2b-155e-410f-8f1b-95bf6a059a3c',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8076,
#    'NewDeaths': 0,
#    'TotalDeaths': 160,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a193ee24-faca-43c0-be40-e88e0a48e3bd',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24059,
#    'NewDeaths': 0,
#    'TotalDeaths': 383,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c3d44afd-72a3-43dd-8225-cdd55557d130',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 86461,
#    'NewDeaths': 0,
#    'TotalDeaths': 1335,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4aa8a1aa-d0d9-471b-8c88-c5a860b240ff',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 829400,
#    'NewDeaths': 0,
#    'TotalDeaths': 8226,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b2b5abbb-c19c-40e2-9e0e-00b100c25723',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1084012,
#    'NewDeaths': 0,
#    'TotalDeaths': 15435,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bfa05d33-cbcb-4004-a35b-e57b70d77420',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1081472,
#    'NewDeaths': 0,
#    'TotalDeaths': 8506,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '905ff634-b53a-4f76-adcd-5e688431e91b',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 377356,
#    'NewDeaths': 0,
#    'TotalDeaths': 919,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '81c00be7-2a97-4550-b1dc-28419009fd90',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3737891,
#    'NewDeaths': 0,
#    'TotalDeaths': 39359,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '792e2493-4c94-4df2-82cb-ba1ef28d01ae',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 81655,
#    'NewDeaths': 0,
#    'TotalDeaths': 796,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2070c48b-d612-45f2-933d-d28853ee36ce',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3051491,
#    'NewDeaths': 0,
#    'TotalDeaths': 5450,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b4f5bb50-a0b8-4d9d-8109-d408d9b3bf40',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15573,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '88764c39-2395-4005-86ae-983df469e6b0',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11724,
#    'NewDeaths': 0,
#    'TotalDeaths': 62,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0e91ac9e-aeec-4c6f-b210-3266d13bd6fe',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 577317,
#    'NewDeaths': 0,
#    'TotalDeaths': 4375,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '748836d7-5837-493e-96c4-e913c298db7c',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 853850,
#    'NewDeaths': 0,
#    'TotalDeaths': 35410,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1fa0f635-add5-4437-acd5-5698484c579d',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 495373,
#    'NewDeaths': 0,
#    'TotalDeaths': 24277,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8f35c272-8125-4d45-9f66-1608806d3804',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 161052,
#    'NewDeaths': 0,
#    'TotalDeaths': 4109,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '55b61212-7a74-4731-8402-d08e22db35f1',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15899,
#    'NewDeaths': 0,
#    'TotalDeaths': 183,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '62baba9f-0790-4be7-b293-5adcce2f4d65',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9723,
#    'NewDeaths': 0,
#    'TotalDeaths': 103,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c115ab18-9aaa-4123-afad-328cd65c25f8',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 542386,
#    'NewDeaths': 0,
#    'TotalDeaths': 2392,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'def1b2ea-c349-4222-a9e9-b17a8f7f6951',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 469455,
#    'NewDeaths': 0,
#    'TotalDeaths': 7489,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3c842554-3674-48ef-acc3-50332ad4fdea',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64221,
#    'NewDeaths': 0,
#    'TotalDeaths': 834,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b6215307-c645-48bf-bbd9-0246e7c90a5b',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 786312,
#    'NewDeaths': 0,
#    'TotalDeaths': 2783,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1470b3c8-ae1e-4ba9-b686-4398e59afd8e',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24323239,
#    'NewDeaths': 0,
#    'TotalDeaths': 141961,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b2d46714-afae-495b-ad65-5e342da19a7a',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 47570,
#    'NewDeaths': 0,
#    'TotalDeaths': 303,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '104acaa9-08e4-4416-ac21-88f9fdce88e6',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11978,
#    'NewDeaths': 0,
#    'TotalDeaths': 365,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bce8d2e9-1acb-4549-b101-a0b61aa97be5',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1641874,
#    'NewDeaths': 0,
#    'TotalDeaths': 16663,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ea7bc688-945e-414e-8462-78c77296ffbe',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 92316,
#    'TotalConfirmed': 18809998,
#    'NewDeaths': 13,
#    'TotalDeaths': 126933,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '79b1e88e-4def-475a-b24c-7f7ed1e7a2fd',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 160819,
#    'NewDeaths': 0,
#    'TotalDeaths': 1445,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '62f51df3-3658-4832-9fac-ff343366f1f9',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2788654,
#    'NewDeaths': 0,
#    'TotalDeaths': 26937,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3a7a1657-c781-4e74-bcb0-3bbf19423dcb',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13936,
#    'NewDeaths': 0,
#    'TotalDeaths': 217,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c44c1fca-7450-4973-8168-c00afcce45a8',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 816136,
#    'NewDeaths': 0,
#    'TotalDeaths': 17238,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1d435ead-bd53-4fd3-a038-723456f5df5d',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36435,
#    'NewDeaths': 0,
#    'TotalDeaths': 440,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '284d6f48-8b0c-4f91-92fe-92e1acc5a26b',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8113,
#    'NewDeaths': 0,
#    'TotalDeaths': 169,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'bcac3aba-2a3f-44d1-b3fc-b0ee695ce5b7',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63194,
#    'NewDeaths': 0,
#    'TotalDeaths': 1226,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e1b3d7fe-d685-4844-97bc-7d734252ac80',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30478,
#    'NewDeaths': 0,
#    'TotalDeaths': 827,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e3e28432-3b8d-4d57-ba5f-6624514e37ef',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e06021f1-7cb5-48e3-8bf5-dcd61e8e293e',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 418300,
#    'NewDeaths': 0,
#    'TotalDeaths': 10857,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '041ecea3-425a-405a-a228-f16be65f720e',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1824089,
#    'NewDeaths': 0,
#    'TotalDeaths': 44961,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '571c339d-4e76-487a-bf5f-122f735fa008',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 170806,
#    'NewDeaths': 0,
#    'TotalDeaths': 91,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '69e2803b-dfce-419d-adee-04a40d755021',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 1549,
#    'TotalConfirmed': 43009390,
#    'NewDeaths': 31,
#    'TotalDeaths': 516510,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '15b68280-93ec-44e1-9414-3391d32522e9',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5962483,
#    'NewDeaths': 0,
#    'TotalDeaths': 153738,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '312c2530-f369-4c7a-bcc7-eb759e1f69a9',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7141033,
#    'NewDeaths': 0,
#    'TotalDeaths': 139610,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '393cf270-482d-4662-af68-74ab9373a668',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2316044,
#    'NewDeaths': 0,
#    'TotalDeaths': 25129,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '018dc168-7d3b-460e-b575-ea8cf6387e1f',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1365467,
#    'NewDeaths': 0,
#    'TotalDeaths': 6638,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5702cbcf-1ba9-4349-a652-4a7057186f3d',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3772751,
#    'NewDeaths': 0,
#    'TotalDeaths': 10431,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e01d2939-8983-46ae-bbdc-ef0e15a67acd',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 61564,
#    'TotalConfirmed': 13861743,
#    'NewDeaths': 93,
#    'TotalDeaths': 157785,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e05e8106-58bd-4db1-b733-d8e689241084',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 128539,
#    'NewDeaths': 0,
#    'TotalDeaths': 2867,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8843e23f-dc24-43d4-b6aa-4e5d8833c6ab',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 39560,
#    'TotalConfirmed': 6100331,
#    'NewDeaths': 66,
#    'TotalDeaths': 27122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '9fee6651-609e-444b-9612-cf7bc066bbc5',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1680179,
#    'NewDeaths': 0,
#    'TotalDeaths': 13959,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4e74d647-9743-4403-a494-30f60a8d4ea2',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1393427,
#    'NewDeaths': 0,
#    'TotalDeaths': 19001,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ef5561cf-cc8c-42ab-891e-18d3b925f343',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 323281,
#    'NewDeaths': 0,
#    'TotalDeaths': 5647,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '397687b3-48f9-424a-a8bd-a0ca77eff299',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3049,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'aefafec2-5a7b-45b1-9c6f-3486cc630637',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9582815,
#    'NewDeaths': 0,
#    'TotalDeaths': 12757,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4e18eb66-cf85-4262-a256-45b9126ca678',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 627342,
#    'NewDeaths': 0,
#    'TotalDeaths': 2553,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '678a8b49-8a1c-40b1-8c17-e7cdebc471b0',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 200818,
#    'NewDeaths': 0,
#    'TotalDeaths': 2980,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '692e9630-4a73-462e-a5b7-8bbe19ebb04e',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 152957,
#    'NewDeaths': 0,
#    'TotalDeaths': 645,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '95855b76-8066-4dde-b295-94b5b6edbfbc',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 771038,
#    'NewDeaths': 0,
#    'TotalDeaths': 5511,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fb2d63b1-a7a9-406b-902b-43ca7265a662',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1088196,
#    'NewDeaths': 0,
#    'TotalDeaths': 10248,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a5b9d587-72c2-4f1f-8be8-a2a89aab7977',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32775,
#    'NewDeaths': 0,
#    'TotalDeaths': 697,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ee074c4e-30ef-4755-b0c3-f220fd6d8716',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7397,
#    'NewDeaths': 0,
#    'TotalDeaths': 294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '01601103-a1c7-4ae1-b49e-3a2f7c7fb603',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 501015,
#    'NewDeaths': 0,
#    'TotalDeaths': 6374,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e179e3fa-b368-4c30-a8eb-381f736942ca',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15312,
#    'NewDeaths': 0,
#    'TotalDeaths': 81,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd4c86752-6dbb-45e6-a8e3-a54c46b0320b',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 992101,
#    'NewDeaths': 0,
#    'TotalDeaths': 8728,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0c18cf37-8ff9-43c2-a1a7-c906b4c3e37c',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 199202,
#    'NewDeaths': 0,
#    'TotalDeaths': 1010,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '711e6f4c-a6c4-429f-a226-c5bf25c86106',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 303354,
#    'NewDeaths': 0,
#    'TotalDeaths': 9180,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '04323646-0d9c-4f19-b020-93bb2eed8229',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63928,
#    'NewDeaths': 0,
#    'TotalDeaths': 1380,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'f41c6db3-94dd-4e64-baee-cc89edde6069',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 85561,
#    'NewDeaths': 0,
#    'TotalDeaths': 2626,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e6b878f1-f1d3-475e-9767-2bc75ddebc9f',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 19105,
#    'TotalConfirmed': 3993124,
#    'NewDeaths': 71,
#    'TotalDeaths': 34400,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fd42e165-d826-4ec0-8a5f-242fc73f881f',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 174658,
#    'NewDeaths': 0,
#    'TotalDeaths': 297,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fd0a925b-a922-4086-899b-67acd363bd05',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30453,
#    'NewDeaths': 0,
#    'TotalDeaths': 727,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fde252ed-e5e4-4237-9722-8e08807e0982',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 74518,
#    'NewDeaths': 0,
#    'TotalDeaths': 622,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '9abf2bf7-2926-43d4-a08a-2803e2f8b05c',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c518dba7-b08c-4fd9-a22d-a2e113334559',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 58662,
#    'NewDeaths': 0,
#    'TotalDeaths': 981,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3e729da9-03af-4886-8980-371323aacceb',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 192558,
#    'NewDeaths': 0,
#    'TotalDeaths': 934,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3fca442c-fbb6-4ad9-9b39-9bd19e29a667',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 4114,
#    'TotalConfirmed': 5633928,
#    'NewDeaths': 141,
#    'TotalDeaths': 322072,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd6ddc31b-c38d-422c-a2a6-1b893e56a134',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3cd815b2-c196-4bc0-bece-c5b31d51ef05',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 510460,
#    'NewDeaths': 0,
#    'TotalDeaths': 11389,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2715d72f-2ef3-402d-b1ae-fde84df54021',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10127,
#    'NewDeaths': 0,
#    'TotalDeaths': 54,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'da6892cb-0455-49f4-ab94-9af0c39fc223',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 916723,
#    'NewDeaths': 0,
#    'TotalDeaths': 2177,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e031a9bf-dc7a-4a21-a3b9-7f339401bb85',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 232193,
#    'NewDeaths': 0,
#    'TotalDeaths': 2696,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5e6a0bf1-483c-45f7-9ae4-3d042fff7208',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1162497,
#    'NewDeaths': 0,
#    'TotalDeaths': 16052,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a780795c-f0ab-4160-95f6-4ea89862bb04',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 225210,
#    'NewDeaths': 0,
#    'TotalDeaths': 2200,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b1d25af1-2118-4919-a4bb-b4b7368272cf',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 608990,
#    'NewDeaths': 0,
#    'TotalDeaths': 19425,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c468927a-652d-4121-a1a3-a860db12950f',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 157523,
#    'NewDeaths': 0,
#    'TotalDeaths': 4016,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2eee7629-9166-4a9d-b052-b501b7305a13',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 978155,
#    'NewDeaths': 0,
#    'TotalDeaths': 11950,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'cd99ebaf-6233-4748-8d52-6698f7092487',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 34823,
#    'TotalConfirmed': 7595517,
#    'NewDeaths': 8,
#    'TotalDeaths': 21814,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8c9b6fb3-f99e-4485-bb06-9e83db91f4fa',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 498474,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0cd4eb85-b400-4f1c-8178-5b16613c92f9',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18290,
#    'NewDeaths': 0,
#    'TotalDeaths': 228,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '0c1ec0bc-8845-4731-95ff-b86f2e4804ef',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8788,
#    'NewDeaths': 0,
#    'TotalDeaths': 308,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '396da93d-9d20-4a51-96b0-de6259f428ce',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 255103,
#    'NewDeaths': 0,
#    'TotalDeaths': 3142,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b6a36db4-154d-44c8-95de-2101b59c70c2',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1379467,
#    'NewDeaths': 0,
#    'TotalDeaths': 2169,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd84d00ff-a075-48fb-9031-9731dbc73f35',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 387505,
#    'NewDeaths': 0,
#    'TotalDeaths': 4250,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b700e320-a754-447b-a923-a3cc4ba312d8',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 303,
#    'TotalConfirmed': 1522191,
#    'NewDeaths': 2,
#    'TotalDeaths': 30331,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c7ed2012-1510-468c-aaf3-2953c0503da1',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3945,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd7a2e4fc-33cc-4be5-b2af-7cbe81aa65b3',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 654380,
#    'NewDeaths': 0,
#    'TotalDeaths': 5628,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5e7a76f2-ab9c-42bc-b8f6-9abae86d1159',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 761508,
#    'NewDeaths': 0,
#    'TotalDeaths': 8156,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '87017a96-dd39-4613-a9ca-628f5f61692d',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 41533,
#    'NewDeaths': 0,
#    'TotalDeaths': 639,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ea91a4a7-3fec-4403-944d-1b582adc4905',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 647099,
#    'NewDeaths': 0,
#    'TotalDeaths': 18586,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6be5416e-5e31-481f-9804-da5197540ec9',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 604,
#    'TotalConfirmed': 3541397,
#    'NewDeaths': 51,
#    'TotalDeaths': 211865,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'f0183bea-7919-4024-bfbc-260c76e651c0',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3674286,
#    'NewDeaths': 0,
#    'TotalDeaths': 58263,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6746bf07-a020-4931-b579-e38f26664219',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5891140,
#    'NewDeaths': 0,
#    'TotalDeaths': 114218,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '422ad149-e3fc-4b1b-a326-607131bdc409',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3458727,
#    'NewDeaths': 0,
#    'TotalDeaths': 21408,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '58866fef-1c9b-4061-b189-ce04f2a40931',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 359956,
#    'NewDeaths': 0,
#    'TotalDeaths': 677,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '74531f1d-8164-4a66-85ae-18d90c6f4d01',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 227124,
#    'NewDeaths': 0,
#    'TotalDeaths': 3127,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2f12ce2c-0fe6-4b03-8dd6-43aec0c65f05',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2816039,
#    'NewDeaths': 0,
#    'TotalDeaths': 64685,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b4b9f384-de80-4577-a1f4-f3b6328381ef',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 30513,
#    'TotalConfirmed': 17327694,
#    'NewDeaths': 422,
#    'TotalDeaths': 357234,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'feaae5f8-a6c7-4f6b-8100-8bf439e063be',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 129647,
#    'NewDeaths': 0,
#    'TotalDeaths': 1459,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a729514a-1af1-4f08-90e1-f5142904b924',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5548,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '9e3f7324-d4b6-441e-a662-aa141efd89d9',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22884,
#    'NewDeaths': 0,
#    'TotalDeaths': 365,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'b0c14335-b188-4a61-b52c-6fd5677e85ce',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8326,
#    'NewDeaths': 0,
#    'TotalDeaths': 106,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2f3d46c7-d8be-43b9-9532-471fa44f91ef',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 111,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '64ce2a10-ba77-4171-b068-b3b1b4b6d2b5',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14870,
#    'NewDeaths': 0,
#    'TotalDeaths': 112,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8774f467-a342-44ef-bfd9-f9d346fd6c7c',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5941,
#    'NewDeaths': 0,
#    'TotalDeaths': 73,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6585d044-5f72-402f-87d6-ce4a866149a2',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 749597,
#    'NewDeaths': 0,
#    'TotalDeaths': 9028,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '73483fea-a993-4791-b194-0410b285aa1b',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 85827,
#    'NewDeaths': 0,
#    'TotalDeaths': 1964,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7dae0a5c-20d1-4e4b-aea2-cf356c0a2f12',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1955280,
#    'NewDeaths': 0,
#    'TotalDeaths': 15687,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '014c31ac-5a98-4259-a574-9470f03fba75',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39797,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e9ccdc79-ac0b-47aa-a067-e87ba69519bc',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7674,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '4deb5cb7-d625-4c54-a51d-c666589b93bf',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1015017,
#    'NewDeaths': 0,
#    'TotalDeaths': 1198,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd6368662-1edb-436c-9d2f-1d2a5932039a',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2351701,
#    'NewDeaths': 0,
#    'TotalDeaths': 19110,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd98e2677-8f70-4314-b4fd-d52830e9c7d8',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 936847,
#    'NewDeaths': 0,
#    'TotalDeaths': 6442,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'ca9631dd-1c4a-4eaf-b6c4-cdf3ec16b287',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9851,
#    'NewDeaths': 0,
#    'TotalDeaths': 127,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '64374a49-4707-4ea7-acd8-928919761bd6',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26410,
#    'NewDeaths': 0,
#    'TotalDeaths': 1361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2c8534b7-0f27-414f-a5a2-910645f7aa2c',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3704218,
#    'NewDeaths': 0,
#    'TotalDeaths': 99881,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'c2d37705-ceab-432b-a7ca-6bdde27d091a',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17093,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '07c62d1c-0d81-45c3-b6df-54ae7969d516',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11324637,
#    'NewDeaths': 0,
#    'TotalDeaths': 101703,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'cb3f6d56-f5b0-4493-8566-e54da3feebc0',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 658197,
#    'NewDeaths': 0,
#    'TotalDeaths': 16431,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3766a41b-4160-448c-8704-2b99b41c32b6',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 61775,
#    'NewDeaths': 0,
#    'TotalDeaths': 4888,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'e73e6a6d-f79d-492b-bda6-edb8b64600de',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 78946,
#    'NewDeaths': 0,
#    'TotalDeaths': 1323,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '08cc074b-92d7-498b-98d8-f71720c25b54',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 69552,
#    'NewDeaths': 0,
#    'TotalDeaths': 1392,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '7b4e5912-ea22-490c-b053-726c7be73abf',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2475687,
#    'NewDeaths': 0,
#    'TotalDeaths': 18053,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'caa010f0-a388-4ca0-8c77-7e793ad0dc74',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3268953,
#    'NewDeaths': 0,
#    'TotalDeaths': 13423,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '06dc162d-6275-4ab2-8e7d-2cc89cb4d4d7',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55558,
#    'NewDeaths': 0,
#    'TotalDeaths': 3127,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '10f3a19c-212f-48ee-b058-a0bb4879e595',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21905,
#    'NewDeaths': 0,
#    'TotalDeaths': 853,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '2f534467-de2d-417e-a88c-142a2c61740f',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17786,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6b3e1ed3-8686-4804-aecf-df161fc61015',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33773,
#    'NewDeaths': 0,
#    'TotalDeaths': 800,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a4f04a69-f971-42cd-8ae9-347a45e997fa',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3377410,
#    'NewDeaths': 0,
#    'TotalDeaths': 24334,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '935ad0d2-0c75-4088-8c7a-f9be73a90599',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22801,
#    'NewDeaths': 0,
#    'TotalDeaths': 129,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '14c6bfca-f870-4360-bd43-f23e3c9b710e',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36878,
#    'NewDeaths': 0,
#    'TotalDeaths': 272,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '190a3266-d028-43e5-9002-612dedca831e',
#    'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3232,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8e299708-96fb-41eb-8271-8bb7461645cc',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 135097,
#    'NewDeaths': 0,
#    'TotalDeaths': 3712,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3b9faebe-9e3e-4786-bdaa-28837000d891',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1029762,
#    'NewDeaths': 0,
#    'TotalDeaths': 28065,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '3cf28f82-25a3-4fea-99de-9ea8a609af38',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14693917,
#    'NewDeaths': 0,
#    'TotalDeaths': 97267,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '91e6bccc-887f-4c21-bc4d-ab52bfe88bf1',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 163688,
#    'NewDeaths': 0,
#    'TotalDeaths': 3595,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'a92a109d-a05d-4f9f-b3e3-c82c24f621b9',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5040518,
#    'NewDeaths': 0,
#    'TotalDeaths': 112459,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '634c346d-354d-417c-8f6e-a600b006fd2c',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 887732,
#    'NewDeaths': 0,
#    'TotalDeaths': 2302,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'fbb3f957-e451-473c-9c30-668cc8950e42',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20243940,
#    'NewDeaths': 0,
#    'TotalDeaths': 164099,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': 'd0ea6200-b54d-479a-842a-6ba4f510a175',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 6623,
#    'TotalConfirmed': 79734788,
#    'NewDeaths': 75,
#    'TotalDeaths': 971162,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1c0fe4df-f6c1-4fbc-a8e2-725e19fc6d34',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 875313,
#    'NewDeaths': 0,
#    'TotalDeaths': 7138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '1ed972db-e7cf-43a9-afd4-c3827be810a1',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 237476,
#    'NewDeaths': 0,
#    'TotalDeaths': 1637,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '040705d7-a82f-4945-ac4d-ccb0b848a561',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 753,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '051587ff-757c-4da8-ae0f-7f9c74960c8e',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 519670,
#    'NewDeaths': 0,
#    'TotalDeaths': 5668,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '5c719820-718a-4482-bb69-99a844c946a8',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7958048,
#    'NewDeaths': 0,
#    'TotalDeaths': 41880,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '8afbce96-7ecd-4653-ad37-4a97403467f9',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11801,
#    'NewDeaths': 0,
#    'TotalDeaths': 2140,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '6735ae99-f98d-4e3c-ae2f-02083117b452',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 315623,
#    'NewDeaths': 0,
#    'TotalDeaths': 3962,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}},
#   {'ID': '75b96d46-88f8-4620-bdf3-1de2e9302a5a',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 244452,
#    'NewDeaths': 0,
#    'TotalDeaths': 5426,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-03-21T17:45:10.368Z',
#    'Premium': {}}],
#  'Date': '2022-03-21T17:45:10.368Z'}

# %% [markdown]
# Let's check it's type- it's a dictionary!

# %%
type(covid_json)
# Out:
# dict

# %% [markdown]
# Now we can use our dictionary and list-indexing skills to access information inside the JSON.

# %%
covid_json['Global']
# Out:
# {'NewConfirmed': 376409,
#  'TotalConfirmed': 470110971,
#  'NewDeaths': 1443,
#  'TotalDeaths': 6072950,
#  'NewRecovered': 0,
#  'TotalRecovered': 0,
#  'Date': '2022-03-21T17:45:10.368Z'}

# %%
covid_json['Global']['NewConfirmed']
# Out:
# 376409

# %% [markdown]
# <a id='oauth'></a>
# # <font style = 'color:blue'> OAuth </font>
#
# ---
#
# **OAuth (Open Authorization)** is simply a secure authorization protocol that often deals with the authorization of a third-party application to access a user's data without exposing their password (e.g., Login with Facebook, gPlus, Twitter in many websites).
#
# For example, before your application can access a user's Facebook data, the user must give your application consent first. As you can imagine, this is a more complex process than before since it involves the user.
#
# There are three parties involved: **OAuth Provider**, **OAuth Client**, and the **Owner**.
#
# - OAuth Client (Application Which wants to access your credential)
# - OAuth Provider (eg. facebook, twitter...)
# - Owner (the one with facebook,twitter.. account )
#
# There are various levels of OAuth access. For security, some APIs (such as the Yelp API) require OAuth access despite there not being any conventional users. These sites require a less complicated OAuth procedure.

# %% [markdown]
# ### Implementing OAuth in Python
#
# There are a number of OAuth libraries available in Python. If you are using a popular website such as Facebook, it is recommended to use their official Python library to handle the OAuth. If not, it is possible to code your own OAuth procedure. Because OAuth requires back-and-forth with your web application, discussing implementation details is outside of the scope of this lesson.
#
# You can read more about OAuth here: http://oauth.net/2/

# %% [markdown]
# ### OAuth Example:  client work with instagram
#
# ![](assets/oAuth1.png)

# %% [markdown]
# ![](assets/oAuth3.png)

# %% [markdown]
# <a name="ind-practice2"></a>
# # <font style = 'color:blue'> Independent Practice: Python APIs </font>
#
# ---
#
#
# Go to http://www.pythonforbeginners.com/api/list-of-python-apis
# or
# https://github.com/realpython/list-of-python-api-wrappers
#
#
# - Choose an API: what data is available with your choosen API?
# - Install Python module (if available for API), try to extract data.
# - Discuss: How could you leverage that api? How could you use the data?
