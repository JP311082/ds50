# %%
import pandas as pd

ORIGINAL_FILE = r'../Data/rm_working_files/right_move_data_eda.csv'
UPDATED_FILE = r'../Data/rm_working_files/right_move_data_eda_update.csv'

feature_columns = ['price', 'bedrooms', 'address', 'latitude', 'longitude', 'propertyType','summary', 'bourough']
rm = pd.read_csv(ORIGINAL_FILE, usecols=feature_columns)

# %%
rm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20169 entries, 0 to 20168
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   identifier    20169 non-null  int64
#  1   price         20169 non-null  int64
#  2   bedrooms      19696 non-null  float64
#  3   address       20169 non-null  object
#  4   latitude      20169 non-null  float64
#  5   longitude     20169 non-null  float64
#  6   propertyType  20169 non-null  object
#  7   summary       20169 non-null  object
#  8   bourough      20169 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
rm.shape
# Out:
# (20169, 8)

# %%
# - Looks like there are a number of duplicate property types in the list which is being caused by capital letters - 
# - Remove all caps 
rm.propertyType.value_counts()
# Out:
# apartment                   6168
# flat                        5520
# terraced house              2163
# semi-detached house         1451
# detached house              1005
# house                        799
# end of terrace house         618
# maisonette                   558
# penthouse                    340
# Studio flat                  217
# retirement property          175
# ground floor flat            144
# bungalow                     125
# town house                   116
# Studio apartment             104
# duplex                        97
# detached bungalow             80
# mews house                    76
# property                      76
# Land                          62
# ground maisonette             43
# semi-detached bungalow        34
# cottage                       32
# block of apartments           21
# link detached house           18
# Property                      16
# park home                     15
# Detached house                14
# Terraced house                13
# Plot                          13
# House                          8
# Parking                        7
# house boat                     7
# Block of Apartments            6
# Semi-detached house            4
# serviced apartment             4
# End of terrace house           3
# chalet                         2
# Penthouse                      2
# Hotel room                     2
# lodge                          2
# Ground floor studio flat       1
# equestrian facility            1
# cluster house                  1
# manor house                    1
# country house                  1
# triplex                        1
# terraced bungalow              1
# garages                        1
# Bungalow                       1
# Name: propertyType, dtype: int64

# %%
rm = rm.apply(lambda x: x.str.lower()if x.dtype =='object' else x)

# %%
rm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20169 entries, 0 to 20168
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   identifier    20169 non-null  int64
#  1   price         20169 non-null  int64
#  2   bedrooms      19696 non-null  float64
#  3   address       20169 non-null  object
#  4   latitude      20169 non-null  float64
#  5   longitude     20169 non-null  float64
#  6   propertyType  20169 non-null  object
#  7   summary       20169 non-null  object
#  8   bourough      20169 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
#There are 473 property listings which do not have details re the number of bedrooms
rm.isnull().sum()
# Out:
# identifier        0
# price             0
# bedrooms        473
# address           0
# latitude          0
# longitude         0
# propertyType      0
# summary           0
# bourough          0
# dtype: int64

# %%
# update studio flat and Ground floor studio flat  = studio apartment as they are the same 
# 321 of the 473 rows where bedroom = NaN are studio apartments so I can update these records to have 0 bedrooms
rm.loc[rm['propertyType'].isin(['studio flat', 'ground floor studio flat']), 'propertyType'] = 'studio apartment'
rm.loc[(rm['bedrooms'].isnull()) & (rm['propertyType'] == 'studio apartment'), 'bedrooms'] = 0

# %%
# I want to see the remaining bedrooms = nan and their corresponding property types

rm[rm.bedrooms.isnull()].groupby(rm['propertyType']).count()
# Out:
#                       identifier  price  bedrooms  address  latitude  \
# propertyType
# block of apartments            6      6         0        6         6
# bungalow                       1      1         0        1         1
# detached house                14     14         0       14        14
# end of terrace house           3      3         0        3         3
# hotel room                     2      2         0        2         2
# house                          8      8         0        8         8
# land                          62     62         0       62        62
# parking                        7      7         0        7         7
# penthouse                      2      2         0        2         2
# plot                          13     13         0       13        13
# property                      16     16         0       16        16
# semi-detached house            4      4         0        4         4
# terraced house                13     13         0       13        13
#
#                       longitude  propertyType  summary  bourough
# propertyType
# block of apartments           6             6        6         6
# bungalow                      1             1        1         1
# detached house               14            14       14        14
# end of terrace house          3             3        3         3
# hotel room                    2             2        2         2
# house                         8             8        8         8
# land                         62            62       62        62
# parking                       7             7        7         7
# penthouse                     2             2        2         2
# plot                         13            13       13        13
# property                     16            16       16        16
# semi-detached house           4             4        4         4
# terraced house               13            13       13        13

# %%
# remove the following property types from the dataset: Land, Parking, Plot, Block of apartments, hotel rooms
rm.drop(rm.loc[rm['propertyType'].isin(['land', 'parking', 'plot','block of apartments','garages', 'hotel room', 'house boat', 'park home'])].index, inplace=True)

# %%
# the remaining property types that do have bedrooms = NaN are as follows:

rm[rm.bedrooms.isnull()].groupby(rm['propertyType']).count()
# Out:
#                       identifier  price  bedrooms  address  latitude  \
# propertyType
# bungalow                       1      1         0        1         1
# detached house                14     14         0       14        14
# end of terrace house           3      3         0        3         3
# house                          8      8         0        8         8
# penthouse                      2      2         0        2         2
# property                      16     16         0       16        16
# semi-detached house            4      4         0        4         4
# terraced house                13     13         0       13        13
#
#                       longitude  propertyType  summary  bourough
# propertyType
# bungalow                      1             1        1         1
# detached house               14            14       14        14
# end of terrace house          3             3        3         3
# house                         8             8        8         8
# penthouse                     2             2        2         2
# property                     16            16       16        16
# semi-detached house           4             4        4         4
# terraced house               13            13       13        13

# %%
rm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20035 entries, 0 to 20168
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   identifier    20035 non-null  int64
#  1   price         20035 non-null  int64
#  2   bedrooms      19974 non-null  float64
#  3   address       20035 non-null  object
#  4   latitude      20035 non-null  float64
#  5   longitude     20035 non-null  float64
#  6   propertyType  20035 non-null  object
#  7   summary       20035 non-null  object
#  8   bourough      20035 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.0+ MB

# %%
# Remove the 61 rows where bedroom = na
# because the bedroom column is the only one with na, we can simply use the dropna function

rm.dropna(inplace=True)

# %%
rm.isnull().sum()
# Out:
# identifier      0
# price           0
# bedrooms        0
# address         0
# latitude        0
# longitude       0
# propertyType    0
# summary         0
# bourough        0
# dtype: int64

# %%
#See of garden is mentioned in the summary 
rm['outdoor space'] = rm['summary'].str.contains('balcony|garden|terrace|yard|acre',regex=True)

# %%
#remove .json from the end of each bourough 
# rm.bourough.str.replace('.json', '')
# df['prod_type'] = df['prod_type'].replace('respon' ,'responsvie')
rm.bourough.replace('.json', '', inplace=True, regex=True)

# %%
rm.to_csv(r'../Data wrangling/ids.csv')

# %%
# - Looks like there are a number of duplicate property types in the list which is being caused by capital letters - 
# - Remove all caps 
rm.propertyType.value_counts()
# Out:
# apartment                 6168
# flat                      5520
# terraced house            2163
# semi-detached house       1451
# detached house            1005
# house                      799
# end of terrace house       618
# maisonette                 558
# penthouse                  340
# studio apartment           322
# retirement property        175
# ground floor flat          144
# bungalow                   125
# town house                 116
# duplex                      97
# detached bungalow           80
# property                    76
# mews house                  76
# ground maisonette           43
# semi-detached bungalow      34
# cottage                     32
# link detached house         18
# serviced apartment           4
# chalet                       2
# lodge                        2
# terraced bungalow            1
# manor house                  1
# triplex                      1
# country house                1
# cluster house                1
# equestrian facility          1
# Name: propertyType, dtype: int64

# %%
#There are too many property types in the list so I have decided to combine the types that are
#similar / the same:
    # apartments, flats, serviced apartment, ground floor flat
    # terraced house, semi-detacthed house, cluster house 
    # detacthed house, house, town house, link detached house
    # duplex,  ground maisonette, triplex 
    # detached bungalow,semi-detached bungalow, 
    # manor house equestrian facility chalet lodge
    
rm.loc[rm.propertyType.isin(['flat','serviced apartment','ground floor flat']), 'propertyType'] = 'apartment' 
rm.loc[rm.propertyType.isin(['terraced house','semi-detacthed house', 'cluster house']), 'propertyType'] = 'terraced house'  
rm.loc[rm.propertyType.isin(['detacthed house','town house', 'house', 'link detached house']), 'propertyType'] = 'detached house'  
rm.loc[rm.propertyType.isin(['duplex','ground maisonette', 'triplex']), 'propertyType'] = 'maisonette'  
rm.loc[rm.propertyType.isin(['detached bungalow','semi-detached bungalow','terraced bungalow']), 'propertyType'] = 'bungalow'  
rm.loc[rm.propertyType.isin(['manor house','equestrian facility', 'chalet', 'lodge']), 'propertyType'] = 'country house'  

rm.propertyType.value_counts()
# Out:
# apartment               11836
# terraced house           2164
# detached house           1938
# semi-detached house      1451
# maisonette                699
# end of terrace house      618
# penthouse                 340
# studio apartment          322
# bungalow                  240
# retirement property       175
# property                   76
# mews house                 76
# cottage                    32
# country house               7
# Name: propertyType, dtype: int64

# %%
# property type = 'property' appears to be a mix of houses and apartments
rm[rm['propertyType'] == 'property']
# Out:
#          price  bedrooms                                address   latitude  \
# 161    1800000       3.0                    arkley lane, barnet  51.653180
# 539     950000       3.0      ravenscroft avenue, golders green  51.576897
# 808     700000       3.0              crescent road, new barnet  51.645714
# 1351    475000       4.0    geary court, geary drive, brentwood  51.626095
# 1750   3500000       2.0            belmont street, london, nw1  51.543900
# ...        ...       ...                                    ...        ...
# 19944  3590000       1.0        marylebone square, moxon street  51.519130
# 20007  3400000       3.0    millbank quarter, westminster, sw1p  51.494760
# 20084  3173000       1.0       marylebone lane, marylebone, w1u  51.518060
# 20103  3173000       1.0        marylebone square, moxon street  51.519130
# 20164  2995000       3.0  park road, st johns wood, london, nw8  51.528000
#
#        longitude propertyType  \
# 161    -0.230322     property
# 539    -0.199075     property
# 808    -0.163772     property
# 1351    0.298930     property
# 1750   -0.150989     property
# ...          ...          ...
# 19944  -0.152810     property
# 20007  -0.125313     property
# 20084  -0.151280     property
# 20103  -0.152810     property
# 20164  -0.164565     property
#
#                                                  summary     bourough  \
# 161    a rare opportunity to acquire a bespoke detach...       barnet
# 539    exclusive marketing and sales agents for this ...       barnet
# 808    a large semi-detached home offering family siz...       barnet
# 1351   **open house saturday 19th 9:30-11:30** call y...        brent
# 1750   a simply stunning loft style apartment set on ...       camden
# ...                                                  ...          ...
# 19944  a third floor, east facing one bedroom apartme...  westminster
# 20007  off plan | completion q1 2022 | 1,485 sq ft | ...  westminster
# 20084  an amazing 1 bedroom apartment situated on the...  westminster
# 20103  we are honoured to present marylebone square. ...  westminster
# 20164  a beautifully designed fourth floor, three bed...  westminster
#
#        outdoor space
# 161             True
# 539             True
# 808             True
# 1351           False
# 1750           False
# ...              ...
# 19944          False
# 20007           True
# 20084           True
# 20103          False
# 20164          False
#
# [76 rows x 9 columns]

# %%
mask = rm['propertyType'] == 'property'
rm.drop(rm[mask].index, inplace=True)

# %%
rm.propertyType.value_counts()
# Out:
# apartment               11836
# terraced house           2164
# detached house           1938
# semi-detached house      1451
# maisonette                699
# end of terrace house      618
# penthouse                 340
# studio apartment          322
# bungalow                  240
# retirement property       175
# mews house                 76
# cottage                    32
# country house               7
# Name: propertyType, dtype: int64

# %%
#pull the postcodes from the address column, they appear to be the last part of the address string, separated by a comma
rm['postcode'] = rm['address'].str.rsplit(',').str[-1]

# %%
#reviewing the postcodes column coloser, it appears that not all postcodes are provided for every address so,
#drop the postcodes column - I will need to find another way of finding these postcodes
#rm.to_csv(r'..\Data Dumps JSON\Examine.csv') 

rm.drop('postcode', axis=1, inplace=True)

# %%
rm.head(7)
# Out:
#       price  bedrooms                                    address   latitude  \
# 0  40000000      10.0                    merton lane, london, n6  51.567700
# 1  40000000      10.0                    merton lane, london, n6  51.567127
# 2  19995000       8.0  totteridge green, totteridge, london, n20  51.628384
# 3  19995000      11.0          grovelands, totteridge green, n20  51.628685
# 4  19500000       6.0             guildens, courtenay avenue, n6  51.571340
# 5  19500000       5.0                cannon lane, hampstead, nw3  51.560200
# 6  17950000       8.0             the bishops avenue, london, n2  51.578700
#
#    longitude    propertyType  \
# 0  -0.155048  detached house
# 1  -0.154896  detached house
# 2  -0.195597  detached house
# 3  -0.196011  detached house
# 4  -0.167616  detached house
# 5  -0.174380  detached house
# 6  -0.169680  detached house
#
#                                              summary bourough  outdoor space
# 0  exceptional contemporary mansion in highgate l...   barnet           True
# 1  located on a sought-after road in the heart of...   barnet           True
# 2  this immaculate home is set in approximately 1...   barnet           True
# 3  set amid 11.5 acres of luscious greenery this ...   barnet           True
# 4  a rare opportunity to purchase a magnificent f...   barnet           True
# 5  cannon lane, in a quiet conservation area in t...   barnet          False
# 6  an opulent seven bedroom house with outstandin...   barnet          False

# %%
rm.to_csv(UPDATED_FILE)
